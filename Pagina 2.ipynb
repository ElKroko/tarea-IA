# %% [markdown]
# # 0. Librerías

# %%
pip install https://github.com/pandas-profiling/pandas-profiling/archive/master.zip
# Out:
# Collecting https://github.com/pandas-profiling/pandas-profiling/archive/master.zipNote: you may need to restart the kernel to use updated packages.
#
#   Using cached https://github.com/pandas-profiling/pandas-profiling/archive/master.zip
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: scipy<1.12,>=1.4.1 in c:\users\n3mes\miniconda3\envs\datascience\lib\site-packages (from ydata-profiling==0.0.dev0) (1.11.1)
# Requirement already satisfied: pandas!=1.4.0,<2.1,>1.1 in c:\users\n3mes\miniconda3\envs\datascience\lib\site-packages (from ydata-profiling==0.0.dev0) (2.0.3)
# Requirement already satisfied: matplotlib<4,>=3.2 in c:\users\n3mes\miniconda3\envs\datascience\lib\site-packages (from ydata-profiling==0.0.dev0) (3.7.1)
# Requirement already satisfied: pydantic<2,>=1.8.1 in c:\users\n3mes\miniconda3\envs\datascience\lib\site-packages (from ydata-profiling==0.0.dev0) (1.10.12)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in c:\users\n3mes\miniconda3\envs\datascience\lib\site-packages (from ydata-profiling==0.0.dev0) (6.0)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in c:\users\n3mes\miniconda3\envs\datascience\lib\site-packages (from ydata-profiling==0.0.dev0) (3.1.2)
# Requirement already satisfied: visions[type_image_path]==0.7.5 in c:\users\n3mes\appdata\roaming\python\python311\site-packages (from ydata-profiling==0.0.dev0) (0.7.5)
# Requirement already satisfied: numpy<1.24,>=1.16.0 in c:\users\n3mes\miniconda3\envs\datascience\lib\site-packages (from ydata-profiling==0.0.dev0) (1.23.5)
# Requirement already satisfied: htmlmin==0.1.12 in c:\users\n3mes\miniconda3\envs\datascience\lib\site-packages (from ydata-profiling==0.0.dev0) (0.1.12)
# Requirement already satisfied: phik<0.13,>=0.11.1 in c:\users\n3mes\appdata\roaming\python\python311\site-packages (from ydata-profiling==0.0.dev0) (0.12.3)
# Requirement already satisfied: requests<3,>=2.24.0 in c:\users\n3mes\appdata\roaming\python\python311\site-packages (from ydata-profiling==0.0.dev0) (2.31.0)
# Requirement already satisfied: tqdm<5,>=4.48.2 in c:\users\n3mes\miniconda3\envs\datascience\lib\site-packages (from ydata-profiling==0.0.dev0) (4.65.0)
# Requirement already satisfied: seaborn<0.13,>=0.10.1 in c:\users\n3mes\miniconda3\envs\datascience\lib\site-packages (from ydata-profiling==0.0.dev0) (0.12.2)
# Requirement already satisfied: multimethod<2,>=1.4 in c:\users\n3mes\appdata\roaming\python\python311\site-packages (from ydata-profiling==0.0.dev0) (1.9.1)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in c:\users\n3mes\miniconda3\envs\datascience\lib\site-packages (from ydata-profiling==0.0.dev0) (0.14.0)
# Requirement already satisfied: typeguard<3,>=2.13.2 in c:\users\n3mes\miniconda3\envs\datascience\lib\site-packages (from ydata-profiling==0.0.dev0) (2.13.3)
# Requirement already satisfied: imagehash==4.3.1 in c:\users\n3mes\appdata\roaming\python\python311\site-packages (from ydata-profiling==0.0.dev0) (4.3.1)
# Requirement already satisfied: wordcloud>=1.9.1 in c:\users\n3mes\appdata\roaming\python\python311\site-packages (from ydata-profiling==0.0.dev0) (1.9.2)
# Requirement already satisfied: dacite>=1.8 in c:\users\n3mes\appdata\roaming\python\python311\site-packages (from ydata-profiling==0.0.dev0) (1.8.1)
# Requirement already satisfied: PyWavelets in c:\users\n3mes\appdata\roaming\python\python311\site-packages (from imagehash==4.3.1->ydata-profiling==0.0.dev0) (1.4.1)
# Requirement already satisfied: pillow in c:\users\n3mes\miniconda3\envs\datascience\lib\site-packages (from imagehash==4.3.1->ydata-profiling==0.0.dev0) (10.0.0)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\n3mes\miniconda3\envs\datascience\lib\site-packages (from visions[type_image_path]==0.7.5->ydata-profiling==0.0.dev0) (23.1.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\n3mes\appdata\roaming\python\python311\site-packages (from visions[type_image_path]==0.7.5->ydata-profiling==0.0.dev0) (3.1)
# Requirement already satisfied: tangled-up-in-unicode>=0.0.4 in c:\users\n3mes\miniconda3\envs\datascience\lib\site-packages (from visions[type_image_path]==0.7.5->ydata-profiling==0.0.dev0) (0.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\n3mes\miniconda3\envs\datascience\lib\site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling==0.0.dev0) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\n3mes\miniconda3\envs\datascience\lib\site-packages (from matplotlib<4,>=3.2->ydata-profiling==0.0.dev0) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\n3mes\miniconda3\envs\datascience\lib\site-packages (from matplotlib<4,>=3.2->ydata-profiling==0.0.dev0) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\n3mes\miniconda3\envs\datascience\lib\site-packages (from matplotlib<4,>=3.2->ydata-profiling==0.0.dev0) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\n3mes\miniconda3\envs\datascience\lib\site-packages (from matplotlib<4,>=3.2->ydata-profiling==0.0.dev0) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\n3mes\miniconda3\envs\datascience\lib\site-packages (from matplotlib<4,>=3.2->ydata-profiling==0.0.dev0) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\n3mes\miniconda3\envs\datascience\lib\site-packages (from matplotlib<4,>=3.2->ydata-profiling==0.0.dev0) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\n3mes\miniconda3\envs\datascience\lib\site-packages (from matplotlib<4,>=3.2->ydata-profiling==0.0.dev0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\n3mes\miniconda3\envs\datascience\lib\site-packages (from pandas!=1.4.0,<2.1,>1.1->ydata-profiling==0.0.dev0) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\n3mes\miniconda3\envs\datascience\lib\site-packages (from pandas!=1.4.0,<2.1,>1.1->ydata-profiling==0.0.dev0) (2023.3)
# Requirement already satisfied: joblib>=0.14.1 in c:\users\n3mes\miniconda3\envs\datascience\lib\site-packages (from phik<0.13,>=0.11.1->ydata-profiling==0.0.dev0) (1.3.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\n3mes\miniconda3\envs\datascience\lib\site-packages (from pydantic<2,>=1.8.1->ydata-profiling==0.0.dev0) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\n3mes\appdata\roaming\python\python311\site-packages (from requests<3,>=2.24.0->ydata-profiling==0.0.dev0) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\n3mes\miniconda3\envs\datascience\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling==0.0.dev0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\n3mes\miniconda3\envs\datascience\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling==0.0.dev0) (2.0.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\n3mes\appdata\roaming\python\python311\site-packages (from requests<3,>=2.24.0->ydata-profiling==0.0.dev0) (2023.7.22)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\n3mes\miniconda3\envs\datascience\lib\site-packages (from statsmodels<1,>=0.13.2->ydata-profiling==0.0.dev0) (0.5.3)
# Requirement already satisfied: colorama in c:\users\n3mes\miniconda3\envs\datascience\lib\site-packages (from tqdm<5,>=4.48.2->ydata-profiling==0.0.dev0) (0.4.6)
# Requirement already satisfied: six in c:\users\n3mes\miniconda3\envs\datascience\lib\site-packages (from patsy>=0.5.2->statsmodels<1,>=0.13.2->ydata-profiling==0.0.dev0) (1.16.0)

# %%
import pandas as pd
import numpy as np
## from pandas_profiling import ProfileReport

# %% [markdown]
# # 1. Carga de datos

# %%
df_lexp = pd.read_csv("content/data/lexp/Life Expectancy Data.csv")

# %%
df_lexp
# Out:
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 0     Afghanistan  2015  Developing              65.0            263.0
# 1     Afghanistan  2014  Developing              59.9            271.0
# 2     Afghanistan  2013  Developing              59.9            268.0
# 3     Afghanistan  2012  Developing              59.5            272.0
# 4     Afghanistan  2011  Developing              59.2            275.0
# ...           ...   ...         ...               ...              ...
# 2933     Zimbabwe  2004  Developing              44.3            723.0
# 2934     Zimbabwe  2003  Developing              44.5            715.0
# 2935     Zimbabwe  2002  Developing              44.8             73.0
# 2936     Zimbabwe  2001  Developing              45.3            686.0
# 2937     Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 0                62     0.01               71.279624         65.0      1154
# 1                64     0.01               73.523582         62.0       492
# 2                66     0.01               73.219243         64.0       430
# 3                69     0.01               78.184215         67.0      2787
# 4                71     0.01                7.097109         68.0      3013
# ...             ...      ...                     ...          ...       ...
# 2933             27     4.36                0.000000         68.0        31
# 2934             26     4.06                0.000000          7.0       998
# 2935             25     4.43                0.000000         73.0       304
# 2936             25     1.72                0.000000         76.0       529
# 2937             24     1.68                0.000000         79.0      1483
#
#       ...  Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  \
# 0     ...    6.0               8.16         65.0        0.1  584.259210
# 1     ...   58.0               8.18         62.0        0.1  612.696514
# 2     ...   62.0               8.13         64.0        0.1  631.744976
# 3     ...   67.0               8.52         67.0        0.1  669.959000
# 4     ...   68.0               7.87         68.0        0.1   63.537231
# ...   ...    ...                ...          ...        ...         ...
# 2933  ...   67.0               7.13         65.0       33.6  454.366654
# 2934  ...    7.0               6.52         68.0       36.7  453.351155
# 2935  ...   73.0               6.53         71.0       39.8   57.348340
# 2936  ...   76.0               6.16         75.0       42.1  548.587312
# 2937  ...   78.0               7.10         78.0       43.5  547.358878
#
#       Population   thinness  1-19 years   thinness 5-9 years  \
# 0     33736494.0                   17.2                 17.3
# 1       327582.0                   17.5                 17.5
# 2     31731688.0                   17.7                 17.7
# 3      3696958.0                   17.9                 18.0
# 4      2978599.0                   18.2                 18.2
# ...          ...                    ...                  ...
# 2933  12777511.0                    9.4                  9.4
# 2934  12633897.0                    9.8                  9.9
# 2935    125525.0                    1.2                  1.3
# 2936  12366165.0                    1.6                  1.7
# 2937  12222251.0                   11.0                 11.2
#
#       Income composition of resources  Schooling
# 0                               0.479       10.1
# 1                               0.476       10.0
# 2                               0.470        9.9
# 3                               0.463        9.8
# 4                               0.454        9.5
# ...                               ...        ...
# 2933                            0.407        9.2
# 2934                            0.418        9.5
# 2935                            0.427       10.0
# 2936                            0.427        9.8
# 2937                            0.434        9.8
#
# [2938 rows x 22 columns]

# %% [markdown]
# - Variable dependiente: Life expectancy
# - Variables independientes: (5)

# %% [markdown]
# # 2. Regresión lineal

# %% [markdown]
# # Clasificación

# %%
# Normalización y estandarización
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

# Encoding
from sklearn import preprocessing
from sklearn.model_selection import train_test_split

# %%
df_lexp.head()

le = preprocessing.LabelEncoder()
country = df_lexp['Country']
status = df_lexp['Status']
enc_status = le.fit_transform(status).reshape(-1,1)
enc_country = le.fit_transform(country).reshape(-1,1)   
df_lexp["Enc_status"] = enc_status
df_lexp["Enc_country"] = enc_country
df_lexp = df_lexp.drop(['Country','Status'], axis=1)
df_lexp
# Out:
#       Year  Life expectancy   Adult Mortality  infant deaths  Alcohol  \
# 0     2015              65.0            263.0             62     0.01
# 1     2014              59.9            271.0             64     0.01
# 2     2013              59.9            268.0             66     0.01
# 3     2012              59.5            272.0             69     0.01
# 4     2011              59.2            275.0             71     0.01
# ...    ...               ...              ...            ...      ...
# 2933  2004              44.3            723.0             27     4.36
# 2934  2003              44.5            715.0             26     4.06
# 2935  2002              44.8             73.0             25     4.43
# 2936  2001              45.3            686.0             25     1.72
# 2937  2000              46.0            665.0             24     1.68
#
#       percentage expenditure  Hepatitis B  Measles    BMI   \
# 0                  71.279624         65.0      1154   19.1
# 1                  73.523582         62.0       492   18.6
# 2                  73.219243         64.0       430   18.1
# 3                  78.184215         67.0      2787   17.6
# 4                   7.097109         68.0      3013   17.2
# ...                      ...          ...       ...    ...
# 2933                0.000000         68.0        31   27.1
# 2934                0.000000          7.0       998   26.7
# 2935                0.000000         73.0       304   26.3
# 2936                0.000000         76.0       529   25.9
# 2937                0.000000         79.0      1483   25.5
#
#       under-five deaths   ...  Diphtheria    HIV/AIDS         GDP  Population  \
# 0                     83  ...         65.0        0.1  584.259210  33736494.0
# 1                     86  ...         62.0        0.1  612.696514    327582.0
# 2                     89  ...         64.0        0.1  631.744976  31731688.0
# 3                     93  ...         67.0        0.1  669.959000   3696958.0
# 4                     97  ...         68.0        0.1   63.537231   2978599.0
# ...                  ...  ...          ...        ...         ...         ...
# 2933                  42  ...         65.0       33.6  454.366654  12777511.0
# 2934                  41  ...         68.0       36.7  453.351155  12633897.0
# 2935                  40  ...         71.0       39.8   57.348340    125525.0
# 2936                  39  ...         75.0       42.1  548.587312  12366165.0
# 2937                  39  ...         78.0       43.5  547.358878  12222251.0
#
#        thinness  1-19 years   thinness 5-9 years  \
# 0                      17.2                 17.3
# 1                      17.5                 17.5
# 2                      17.7                 17.7
# 3                      17.9                 18.0
# 4                      18.2                 18.2
# ...                     ...                  ...
# 2933                    9.4                  9.4
# 2934                    9.8                  9.9
# 2935                    1.2                  1.3
# 2936                    1.6                  1.7
# 2937                   11.0                 11.2
#
#       Income composition of resources  Schooling  Enc_status  Enc_country
# 0                               0.479       10.1           1            0
# 1                               0.476       10.0           1            0
# 2                               0.470        9.9           1            0
# 3                               0.463        9.8           1            0
# 4                               0.454        9.5           1            0
# ...                               ...        ...         ...          ...
# 2933                            0.407        9.2           1          192
# 2934                            0.418        9.5           1          192
# 2935                            0.427       10.0           1          192
# 2936                            0.427        9.8           1          192
# 2937                            0.434        9.8           1          192
#
# [2938 rows x 22 columns]

# %%
X = df_lexp.drop(columns=['Enc_status'])  # Input features, all columns except 'Status'
Y = df_lexp['Enc_status']  # Output variable, 'Status' column


# Assuming numeric columns in X need to be standardized
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)


X_train, X_test, Y_train, Y_test = train_test_split(X_scaled, Y, test_size=0.2, random_state=42)

print(X.isnull().sum())
# Out:
# Year                                 0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# Enc_country                          0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

# Create an imputer to fill missing values with the mean
imputer = SimpleImputer(strategy='mean')

# Fit the imputer on the training data and transform both training and testing data
X_train_imputed = imputer.fit_transform(X_train)
X_test_imputed = imputer.transform(X_test)

# %%
from sklearn.neighbors import KNeighborsClassifier

# Initialize the KNN classifier
k = 5  # Number of neighbors to consider (can be adjusted)
knn_classifier = KNeighborsClassifier(n_neighbors=k)

# Train the model on the training data
knn_classifier.fit(X_train_imputed, Y_train)

# Predict 'Status' on the test set
Y_pred = knn_classifier.predict(X_test_imputed)

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# Create a confusion matrix
confusion_mat = confusion_matrix(Y_test, Y_pred)

# Get the class labels from the 'Status' column
class_labels = np.unique(Y_train)

# Create a heatmap for the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(confusion_mat, annot=True, fmt="d", cmap="Blues", xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted Class')
plt.ylabel('Actual Class')
plt.title('Confusion Matrix sin PCA')
plt.show()

# %% [markdown]
# ## usando PCA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# Assuming your dataset is stored in a DataFrame named 'df'
# Separate the dependent variable 'Status' from the independent variables 'X'
X = df_lexp.drop(columns=['Enc_status'])
Y = df_lexp['Enc_status']

# Impute missing values
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy='mean')
X_imputed = imputer.fit_transform(X)

# Standardize the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_imputed)

# Apply PCA to reduce the data to 2 components
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# Create a DataFrame with the PCA results and add the 'Status' column
pca_df = pd.DataFrame(data=X_pca, columns=['PC1', 'PC2'])
pca_df['Enc_status'] = Y

# Visualize the data in a scatter plot
plt.figure(figsize=(8, 6))
sns.scatterplot(x='PC1', y='PC2', hue='Enc_status', data=pca_df, palette='viridis', alpha=0.7)
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA Visualization')
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

# Split the PCA-transformed data into training and testing sets
X_train_pca, X_test_pca, Y_train, Y_test = train_test_split(X_pca, Y, test_size=0.2, random_state=42)

# Initialize the KNN classifier
k = 5  # Number of neighbors to consider (can be adjusted)
knn_classifier = KNeighborsClassifier(n_neighbors=k)

# Train the model on the training data
knn_classifier.fit(X_train_pca, Y_train)

# Predict 'Status' on the test set
Y_pred = knn_classifier.predict(X_test_pca)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Combine the PCA-transformed data and predicted class labels
pca_result_df = pd.DataFrame(data=X_test_pca, columns=['PC1', 'PC2'])
pca_result_df['Predicted_Status'] = Y_pred

# Visualize the data in a scatter plot with the predicted classes
plt.figure(figsize=(8, 6))
sns.scatterplot(x='PC1', y='PC2', hue='Predicted_Status', data=pca_result_df, palette='viridis', alpha=0.7)
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('KNN Classification with PCA')
plt.show()

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

# Calculate the confusion matrix
confusion_mat = confusion_matrix(Y_test, Y_pred)

# Calculate accuracy
accuracy = accuracy_score(Y_test, Y_pred)

# Calculate precision, recall, and F1-score for each class
precision = precision_score(Y_test, Y_pred, average=None)
recall = recall_score(Y_test, Y_pred, average=None)
f1 = f1_score(Y_test, Y_pred, average=None)

# Display the results
print("Confusion Matrix:")
print(confusion_mat)
print("\nAccuracy:", accuracy)

# Print precision, recall, and F1-score for each class
for idx, class_label in enumerate(np.unique(Y_test)):
    print(f"\nClass: {class_label}")
    print(f"Precision: {precision[idx]}")
    print(f"Recall: {recall[idx]}")
    print(f"F1-score: {f1[idx]}")
# Out:
# Confusion Matrix:
# [[ 75  22]
#  [ 25 466]]
#
# Accuracy: 0.9200680272108843
#
# Class: 0
# Precision: 0.75
# Recall: 0.7731958762886598
# F1-score: 0.7614213197969544
#
# Class: 1
# Precision: 0.9549180327868853
# Recall: 0.9490835030549898
# F1-score: 0.9519918283963228
