# %% [markdown]
# # 0. Librerías

# %%
import pandas as pd
import numpy as np
from sklearn import datasets
import matplotlib.pyplot as plt

from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import train_test_split

# %% [markdown]
# # 1. Carga de datos

# %%
df_lexp = pd.read_csv("content/data/lexp/Life Expectancy Data.csv")

# %%
df_lexp
# Out:
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 0     Afghanistan  2015  Developing              65.0            263.0
# 1     Afghanistan  2014  Developing              59.9            271.0
# 2     Afghanistan  2013  Developing              59.9            268.0
# 3     Afghanistan  2012  Developing              59.5            272.0
# 4     Afghanistan  2011  Developing              59.2            275.0
# ...           ...   ...         ...               ...              ...
# 2933     Zimbabwe  2004  Developing              44.3            723.0
# 2934     Zimbabwe  2003  Developing              44.5            715.0
# 2935     Zimbabwe  2002  Developing              44.8             73.0
# 2936     Zimbabwe  2001  Developing              45.3            686.0
# 2937     Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# ...

# %%
df_lexp.columns = df_lexp.columns.str.lower().str.replace(' ', '')
df_lexp
# Out:
#           country  year      status  lifeexpectancy  adultmortality  \
# 0     Afghanistan  2015  Developing            65.0           263.0
# 1     Afghanistan  2014  Developing            59.9           271.0
# 2     Afghanistan  2013  Developing            59.9           268.0
# 3     Afghanistan  2012  Developing            59.5           272.0
# 4     Afghanistan  2011  Developing            59.2           275.0
# ...           ...   ...         ...             ...             ...
# 2933     Zimbabwe  2004  Developing            44.3           723.0
# 2934     Zimbabwe  2003  Developing            44.5           715.0
# 2935     Zimbabwe  2002  Developing            44.8            73.0
# 2936     Zimbabwe  2001  Developing            45.3           686.0
# 2937     Zimbabwe  2000  Developing            46.0           665.0
#
#       infantdeaths  alcohol  percentageexpenditure  hepatitisb  measles  ...  \
# ...

# %% [markdown]
# - Variable dependiente: Life expectancy
# - Variables independientes:
#   1. Alcohol: Alcohol, recorded per capita (15+) consumption (in litres of pure alcohol)
#   2. Percentage expenditure: Expenditure on health as a percentage of Gross Domestic Product per capita(%)
#   3. BMI: Average Body Mass Index of entire population
#   4. Polio: Polio (Pol3) immunization coverage among 1-year-olds (%)
#   5. HIV/AIDS: Deaths per 1 000 live births HIV/AIDS (0-4 years)

# %%
contiene_nan = df_lexp[['country', 'year', 'status', 'lifeexpectancy', 'adultmortality',
       'infantdeaths', 'alcohol', 'percentageexpenditure', 'hepatitisb',
       'measles', 'bmi', 'under-fivedeaths', 'polio', 'totalexpenditure',
       'diphtheria', 'hiv/aids', 'gdp', 'population', 'thinness1-19years',
       'thinness5-9years', 'incomecompositionofresources', 'schooling']].isna().sum() #retorna cuantos NaN hay en una columna
contiene_nan
# Out:
# country                           0
# year                              0
# status                            0
# lifeexpectancy                   10
# adultmortality                   10
# infantdeaths                      0
# alcohol                         194
# percentageexpenditure             0
# hepatitisb                      553
# measles                           0
# bmi                              34
# under-fivedeaths                  0
# polio                            19
# totalexpenditure                226
# diphtheria                       19
# hiv/aids                          0
# gdp                             448
# population                      652
# thinness1-19years                34
# thinness5-9years                 34
# incomecompositionofresources    167
# schooling                       163
# dtype: int64

# %% [markdown]
# # 2. Regresión lineal

# %%
df_lexp.columns
# Out:
# Index(['country', 'year', 'status', 'lifeexpectancy', 'adultmortality',
#        'infantdeaths', 'alcohol', 'percentageexpenditure', 'hepatitisb',
#        'measles', 'bmi', 'under-fivedeaths', 'polio', 'totalexpenditure',
#        'diphtheria', 'hiv/aids', 'gdp', 'population', 'thinness1-19years',
#        'thinness5-9years', 'incomecompositionofresources', 'schooling'],
#       dtype='object')

# %%
# Out:
# country                         False
# year                            False
# status                          False
# lifeexpectancy                   True
# adultmortality                   True
# infantdeaths                    False
# alcohol                          True
# percentageexpenditure           False
# hepatitisb                       True
# measles                         False
# bmi                              True
# under-fivedeaths                False
# polio                            True
# totalexpenditure                 True
# diphtheria                       True
# hiv/aids                        False
# gdp                              True
# population                       True
# thinness1-19years                True
# thinness5-9years                 True
# incomecompositionofresources     True
# schooling                        True
# dtype: bool

# %%
df_Y=df_lexp["lifeexpectancy"] #Variable dependiente
df_X=df_lexp[["alcohol", "percentageexpenditure", "bmi", "polio", "hiv/aids"]]#Variable independiente


X_train, X_test, Y_train, Y_test = train_test_split(df_X, df_Y, test_size=0.3, random_state=771)

# %%
# Creamos el objeto de regresion lineal!!!!!
reg_lineal = linear_model.LinearRegression()

# Entrenamos el modelo con los datos de entrenamiento
reg_lineal.fit(X_train, Y_train)

# Hacemos predicciones!!!!
y_predicted = reg_lineal.predict(X_test) # hacemos predicciones de los datos de test

# ******************** ACA SE TERMINA LA REGRESION **************************************


# Los coeficientes
print('Coefficients: \n', 'Intercepto: ',reg_lineal.intercept_, '\nLos demas parametros betas:',reg_lineal.coef_)

# ******************** ACA SE CALCULAN LAS METRICAS **************************************
# El mean squared error!!!!
print('Mean squared error: %.2f'
      % mean_squared_error(Y_test, y_predicted))

# El mean absolute error!!!!
print('Mean absolute error: %.2f'
      % mean_absolute_error(Y_test, y_predicted))

# El R2!!!!
print('Coefficient of determination: %.2f'
      % r2_score(Y_test, y_predicted))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 5
#       2 reg_lineal = linear_model.LinearRegression()
#       4 # Entrenamos el modelo con los datos de entrenamiento
# ----> 5 reg_lineal.fit(X_train, Y_train)
#       7 # Hacemos predicciones!!!!
#       8 y_predicted = reg_lineal.predict(X_test) # hacemos predicciones de los datos de test
#
# File c:\Users\alanz\miniconda3\envs\DataScience\Lib\site-packages\sklearn\linear_model\_base.py:648, in LinearRegression.fit(self, X, y, sample_weight)
#     644 n_jobs_ = self.n_jobs
#     646 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 648 X, y = self._validate_data(
#     649     X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     650 )
#     652 sample_weight = _check_sample_weight(
#     653     sample_weight, X, dtype=X.dtype, only_non_negative=True
#     654 )
# ...
